# %% [markdown]
# # Phase 2: Model Setup, QLoRA Configuration & Baseline Evaluation
# **Project:** Efficient Chain-of-Thought (CoT) Distillation in Small Language Models
# **Goal:** Load unmodified base Qwen2.5-3B model and establish zero-shot baseline benchmarks.

# %%
# Run Phase 2 script directly
# !python run_phase2.py
