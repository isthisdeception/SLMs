# %% [markdown]
# # Phase 4: Post-Training Evaluation & Analysis
# **Project:** Efficient Chain-of-Thought (CoT) Distillation in Small Language Models
# **Goal:** Benchmark fine-tuned SFT model against zero-shot baseline and generate publication figures.

# %%
# Run Phase 4 evaluation and plotting script
# !python run_phase4.py
